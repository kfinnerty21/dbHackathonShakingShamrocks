# %%
import pandas as pd
from faker import Faker
import random
import datetime
import math

# %%
def month_range(start, periods=12):
    rng = pd.date_range(pd.Timestamp(start)-pd.offsets.MonthBegin(),
                        periods=periods,
                        freq='MS')
    ret = (rng + pd.offsets.Day(pd.Timestamp(start).day-1)).to_series()
    ret.loc[ret.dt.month > rng.month] -= pd.offsets.MonthEnd(1)
    return pd.DatetimeIndex(ret)

# %% [markdown]
# Create An Account Profile

# %%
def payment_generator(payment, n=48):
    
    
    if payment['freq']=='M':
        df = pd.DataFrame(data={'dates': month_range(payment['start_date'], n)})
    else:
        df = pd.DataFrame(data={'dates': pd.date_range(payment['start_date'], periods=n, freq=payment['freq'])})
    
    df['account_name'] = payment['account_name'] 
    df['account_IBAN'] = payment['account_IBAN']
    df['other_account_name'] = payment['other_account_name']
    df['Type'] = payment['Type']
    
    if payment['amount']['variable'] == 'False':
        df['amount'] = payment['amount']['base']
    
    if payment['amount']['variable'] == 'True':
        df['amount'] = payment['amount']['base']
        df['amount'] = df['amount'].apply(lambda x: x + random.uniform(payment['amount']['var'], 0))
    
    return df

# %%
fake = Faker()

# %%
name = fake.name()
account_IBAN = fake.bban()
payments_norm = [{
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Wages MyOrg',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': 2600.0
    },
    'start_date': '2018-02-20',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Rent - apt 12',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -1500.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Phone',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -20.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Subscription',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -50.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Utilities',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'True',
        'base': -200.0,
        'var': -100.0
    },
    'start_date': '2018-02-28',
    'freq': '2M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Car',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -250.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Medical Subscription',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -150.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Medical Session',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -200.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Food Desc',
    'other_account_IBAN': fake.bban(),
    'Type': 'Irregular',
    'amount': {
        'variable': 'True',
        'base': - 5.0,
        'var': - 6.0
    },   
    'start_date': '2018-02-28',
    'freq': '7D'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Food Reg',
    'other_account_IBAN': fake.bban(),
    'Type': 'Irregular',
    'amount': {
        'variable': 'True',
        'base': - 200.0,
        'var': - 100.0
    },   
    'start_date': '2018-02-28',
    'freq': '7D'}
]

payments_impluse = [{
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 20.0,
        'var': - 50.0
    },
    'start_date': '2018-03-28',
    'freq': '7D',
    'number': 2},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 240.0,
        'var': - 200.0
    },
    'start_date': '2018-04-28',
    'freq': '1D',
    'number': 1},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 140.0,
        'var': - 50.0
    },
    'start_date': '2018-08-28',
    'freq': '1H',
    'number': 6}]


name = fake.name()
account_IBAN = fake.bban()
payments_norm += [{
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Wages MyOrg',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': 2300.0
    },
    'start_date': '2018-02-15',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Rent - apt 12',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -1200.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Phone',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -18.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Subscription',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -55.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Utilities',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'True',
        'base': -180.0,
        'var': -100.0
    },
    'start_date': '2018-02-28',
    'freq': '2M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Car',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -330.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Medical Subscription',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -80.0
    },
    'start_date': '2018-02-28',
    'freq': 'M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Medical Session',
    'other_account_IBAN': fake.bban(),
    'Type': 'Regular',
    'amount': {
        'variable': 'False',
        'base': -200.0
    },
    'start_date': '2018-02-28',
    'freq': '2M'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Food Desc',
    'other_account_IBAN': fake.bban(),
    'Type': 'Irregular',
    'amount': {
        'variable': 'True',
        'base': - 5.0,
        'var': - 6.0
    },   
    'start_date': '2018-02-28',
    'freq': '7D'},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': 'Food Reg',
    'other_account_IBAN': fake.bban(),
    'Type': 'Irregular',
    'amount': {
        'variable': 'True',
        'base': - 200.0,
        'var': - 100.0
    },   
    'start_date': '2018-02-25',
    'freq': '7D'}
]

payments_impluse += [{
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 60.0,
        'var': - 40.0
    },
    'start_date': '2018-03-28',
    'freq': '7D',
    'number': 7},
    {
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 340.0,
        'var': - 100.0
    },
    'start_date': '2018-04-28',
    'freq': 'D',
    'number': 10},
{
    'account_name': name,
    'account_IBAN': account_IBAN,
    'other_account_name': fake.company_suffix(),
    'other_account_IBAN': fake.bban(),
    'Type': 'Discretionary',
    'amount': {
        'variable': 'True',
        'base': - 99.0,
        'var': - 199.0
    },
    'start_date': '2018-08-28',
    'freq': '1H',
    'number': 6}]


list_impluse = [payment_generator(x, x['number']) for x in payments_impluse]
df_impluse = pd.concat(list_impluse)
df_impluse['dates'] = df_impluse['dates'].dt.strftime('%Y-%m-%d %H:%M:%S')
df_impluse['time_offset'] = 0
df_impluse['time_offset'] = df_impluse['time_offset'].apply(lambda x: x + random.uniform(0, 30))
df_impluse['dates'] = pd.to_datetime(df_impluse['dates']) + pd.to_timedelta(df_impluse['time_offset'], unit='m')

list_norm = [payment_generator(x) for x in payments_norm]
df_norm = pd.concat(list_norm)
df_norm['dates'] = df_norm['dates'].dt.strftime('%Y-%m-%d %H:%M:%S')
df_norm['time_offset'] = 0
df_norm['time_offset'] = df_norm['time_offset'].apply(lambda x: x + random.uniform(0, 30))
df_norm['dates'] = pd.to_datetime(df_norm['dates']) + pd.to_timedelta(df_norm['time_offset'], unit='h')

df_ = pd.concat([df_impluse, df_norm])
df_.reset_index(inplace=True,drop=True)
df_.sort_values(by='dates', inplace=True)
df_.reset_index(inplace=True, drop=True)
df_['balance'] = df_['amount'].cumsum()
df_['dates'] = df_['dates'].dt.strftime('%Y-%m-%d %H:%M:%S')

df_.drop(columns=['time_offset'], inplace=True)
               
df_.head(50)
# Out:
#                   dates  account_name        account_IBAN  \
# 0   2018-02-15 13:41:23  Kelly Wilson  YEYT82839638951373
# 1   2018-02-20 16:18:25   David Singh  ODEC23606947923391
# 2   2018-02-26 04:33:54  Kelly Wilson  YEYT82839638951373
# 3   2018-02-28 02:10:27  Kelly Wilson  YEYT82839638951373
# 4   2018-02-28 02:51:59  Kelly Wilson  YEYT82839638951373
# 5   2018-02-28 04:25:39   David Singh  ODEC23606947923391
# 6   2018-02-28 05:56:51  Kelly Wilson  YEYT82839638951373
# 7   2018-02-28 11:44:43   David Singh  ODEC23606947923391
# 8   2018-02-28 12:35:04  Kelly Wilson  YEYT82839638951373
# 9   2018-02-28 17:44:33  Kelly Wilson  YEYT82839638951373
# 10  2018-02-28 18:35:04  Kelly Wilson  YEYT82839638951373
# 11  2018-02-28 18:54:51   David Singh  ODEC23606947923391
# 12  2018-02-28 19:30:03   David Singh  ODEC23606947923391
# 13  2018-02-28 20:07:25   David Singh  ODEC23606947923391
# 14  2018-02-28 21:59:02   David Singh  ODEC23606947923391
# ...

# %% [markdown]
# Save File for later processing

# %%
df_.to_csv('gs://shakingshamrocks_eu/test_data_3_sec.csv')

# %% [markdown]
# Split into train and test data

# %%
df_train = df_.iloc[:700,:] 
df_test = df_.iloc[701:,:]

# %% [markdown]
# Predict Shortfall

# %%
def find_incommings(df_user):
    
    # segment into months
    df_user['year'] = pd.DatetimeIndex(df_user['dates']).year
    df_user['month'] = pd.DatetimeIndex(df_user['dates']).month
    
    # find average income per month
    df_in = df_user[df_user['amount']>0]
    other_account_name = df_in['other_account_name'].unique()
    
    # find average gap in payments
    incomings = {}
    for payment in other_account_name:
        
        df_tmp = df_in[df_in['other_account_name']== payment].copy()
        df_tmp.sort_values(by='dates', inplace=True)
        df_tmp.reset_index(inplace=True, drop=True)
        df_tmp['diff_days'] = pd.to_datetime(df_tmp['dates']).diff().dt.days.fillna(0, downcast='infer')
        
        incomings[payment] = {}
        incomings[payment]['freq'] = math.ceil(df_tmp['diff_days'].mean())
        incomings[payment]['amount'] = df_tmp['amount'].mean()
        incomings[payment]['start_date'] = df_tmp['dates'].min()
           
    return incomings


def find_outgoings(df_user):
    
    # segment into months
    df_user['year'] = pd.DatetimeIndex(df_user['dates']).year
    df_user['month'] = pd.DatetimeIndex(df_user['dates']).month
    
    # find average income per month
    df_in = df_user[df_user['amount']<0]
    other_account_name = df_in['other_account_name'].unique()
        
    # find average gap in payments
    outgoings = {}
    for payment in other_account_name:
        
        df_tmp = df_in[df_in['other_account_name']== payment].copy()
        df_tmp.sort_values(by='dates', inplace=True)
        df_tmp.reset_index(inplace=True, drop=True)
        df_tmp['diff_days'] = pd.to_datetime(df_tmp['dates']).diff().dt.days.fillna(0, downcast='infer')
        
        outgoings[payment] = {}
        outgoings[payment]['freq'] = math.ceil(df_tmp['diff_days'].mean())
        outgoings[payment]['amount'] = df_tmp['amount'].mean()
        outgoings[payment]['start_date'] = df_tmp['dates'].min()
        
        if outgoings[payment]['freq'] > 25:
            outgoings[payment]['Type'] = 'Regular'
        
        if (outgoings[payment]['freq'] >= 7) & (outgoings[payment]['freq'] < 25):
            outgoings[payment]['Type'] = 'Irregular'
            
        if outgoings[payment]['freq'] < 7:
            outgoings[payment]['Type'] = 'Discretionary'
           
    return outgoings


def build_predicted_in_out(user, incommings, outgoings, end_date):
    
    
    in_list = []
    for i in incommings.keys():    
            
        df = pd.DataFrame(data={'dates': pd.date_range(incommings[i]['start_date'], end_date, freq='MS')})
        df['amount_in'] = incommings[i]['amount']
        in_list.append(df)
    
    out_list = []
    for i in outgoings.keys(): 
        
        if outgoings[i]['Type'] == 'Regular':
        
            df = pd.DataFrame(data={'dates': pd.date_range(outgoings[i]['start_date'], end_date, freq=str(outgoings[i]['freq'])+'D')})
            df['amount_out_reg'] = outgoings[i]['amount']
            out_list.append(df)            
        
    df = pd.concat(in_list + out_list)
    df.reset_index(inplace=True,drop=True)
    df.sort_values(by='dates', inplace=True)
    df.reset_index(inplace=True, drop=True)
    df.fillna(0, inplace=True)

    # bucket into months
    df['year'] = pd.DatetimeIndex(df['dates']).year
    df['month'] = pd.DatetimeIndex(df['dates']).month
    
    return df

# %%
# build testing logic from here down to create decector

unique_name = df_['account_name'].unique()

# %%
df_test = df_train[df_['account_name']==unique_name[0]].copy()

# %%
incommings_payments = find_incommings(df_test.copy())

# %%
outgoing_payments = find_outgoings(df_test.copy())

# %%
df_tmp = build_predicted_in_out(unique_name[0], incommings_payments, outgoing_payments, '2024-01-01 00:00:00')

# %%
gf_payment_pattern_reg = df_tmp.groupby(['year','month'])[['amount_in','amount_out']].sum()
gf_payment_pattern_reg['buffer'] = gf_payment_pattern_reg['amount_in'] + gf['amount_out']
gf_payment_pattern_reg.head(10)
# Out:
#             amount_in   amount_out       buffer
# year month
# 2018 2            0.0 -1883.000000 -1883.000000
#      3         2300.0 -1912.079507   387.920493
#      4         2300.0 -2112.079507   187.920493
#      5         2300.0 -1683.000000   617.000000
#      6         2300.0 -2112.079507   187.920493
#      7         2300.0 -1683.000000   617.000000
#      8         2300.0 -2112.079507   187.920493
#      9         2300.0 -1683.000000   617.000000
#      10        2300.0 -2112.079507   187.920493
#      11        2300.0 -1683.000000   617.000000

# %% [markdown]
# For tansactions - raise alert
