# %%
import pandas as pd
import math

# %%
df = pd.read_csv('gs://shakingshamrocks_eu/test_data_3_sec.csv')

# %%
df = df.drop(df.columns[0],axis = 1)

# %%
def find_incommings(df_user):
    
    # segment into months
    df_user['year'] = pd.DatetimeIndex(df_user['dates']).year
    df_user['month'] = pd.DatetimeIndex(df_user['dates']).month
    
    # find average income per month
    df_in = df_user[df_user['amount']>0]
    other_account_name = df_in['other_account_name'].unique()
    
    # find average gap in payments
    incomings = {}
    for payment in other_account_name:
        
        df_tmp = df_in[df_in['other_account_name']== payment].copy()
        df_tmp.sort_values(by='dates', inplace=True)
        df_tmp.reset_index(inplace=True, drop=True)
        df_tmp['diff_days'] = pd.to_datetime(df_tmp['dates']).diff().dt.days.fillna(0, downcast='infer')
        
        incomings[payment] = {}
        incomings[payment]['freq'] = math.ceil(df_tmp['diff_days'].mean())
        incomings[payment]['amount'] = df_tmp['amount'].mean()
        incomings[payment]['start_date'] = df_tmp['dates'].min()
           
    return incomings


def find_outgoings(df_user):
    
    # segment into months
    df_user['year'] = pd.DatetimeIndex(df_user['dates']).year
    df_user['month'] = pd.DatetimeIndex(df_user['dates']).month
    
    # find average income per month
    df_in = df_user[df_user['amount']<0]
    other_account_name = df_in['other_account_name'].unique()
        
    # find average gap in payments
    outgoings = {}
    for payment in other_account_name:
        
        df_tmp = df_in[df_in['other_account_name']== payment].copy()
        df_tmp.sort_values(by='dates', inplace=True)
        df_tmp.reset_index(inplace=True, drop=True)
        df_tmp['diff_days'] = pd.to_datetime(df_tmp['dates']).diff().dt.days.fillna(0, downcast='infer')
        
        outgoings[payment] = {}
        outgoings[payment]['freq'] = math.ceil(df_tmp['diff_days'].mean())
        outgoings[payment]['amount'] = df_tmp['amount'].mean()
        outgoings[payment]['start_date'] = df_tmp['dates'].min()
        
        if outgoings[payment]['freq'] > 25:
            outgoings[payment]['Type'] = 'Regular'
        
        if (outgoings[payment]['freq'] >= 7) & (outgoings[payment]['freq'] < 25):
            outgoings[payment]['Type'] = 'Irregular'
            
        if outgoings[payment]['freq'] < 7:
            outgoings[payment]['Type'] = 'Discretionary'
           
    return outgoings


def build_predicted_in_out(user, incommings, outgoings, end_date):
    
    
    in_list = []
    for i in incommings.keys():    
            
        df = pd.DataFrame(data={'dates': pd.date_range(incommings[i]['start_date'], end_date, freq='MS')})
        df['amount_in'] = incommings[i]['amount']
        in_list.append(df)
    
    out_list = []
    for i in outgoings.keys(): 
        
        if outgoings[i]['Type'] == 'Regular':
        
            df = pd.DataFrame(data={'dates': pd.date_range(outgoings[i]['start_date'], end_date, freq=str(outgoings[i]['freq'])+'D')})
            df['amount_out_reg'] = outgoings[i]['amount']
            out_list.append(df)            
        
    df = pd.concat(in_list + out_list)
    df.reset_index(inplace=True,drop=True)
    df.sort_values(by='dates', inplace=True)
    df.reset_index(inplace=True, drop=True)
    df.fillna(0, inplace=True)

    # bucket into months
    df['year'] = pd.DatetimeIndex(df['dates']).year
    df['month'] = pd.DatetimeIndex(df['dates']).month
    
    return df

# %%
#df_train = df.iloc[:700,:] 
#df_test = df.iloc[701:,:]

# %%
# build testing logic from here down to create decector

unique_name = df['account_name'].unique()

# %%
unique_name
# Out:
# array(['Katherine Valencia', 'Patrick Hamilton'], dtype=object)

# %%
#df_test = df_train[df['account_name']==unique_name[0]].copy()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
incommings_payments = find_incommings(df.copy())

# %%
outgoing_payments = find_outgoings(df.copy())

# %%
incommings_payments
# Out:
# {'Wages MyOrg': {'freq': 15,
#   'amount': 2450.0,
#   'start_date': '2018-02-16 02:17:13'}}

# %%
df_tmp = build_predicted_in_out(unique_name[1], incommings_payments, outgoing_payments, '2024-01-01 00:00:00')

# %%
df_tmp.head()
# Out:
#                 dates  amount_in  amount_out_reg  year  month
# 0 2018-02-28 07:10:24        0.0     -238.924523  2018      2
# 1 2018-02-28 07:38:44        0.0     -200.000000  2018      2
# 2 2018-03-01 02:17:13     2450.0        0.000000  2018      3
# 3 2018-03-30 07:10:24        0.0     -238.924523  2018      3
# 4 2018-03-30 07:38:44        0.0     -200.000000  2018      3

# %%
gf_payment_pattern_reg = df_tmp.groupby(['year','month'])[['amount_in','amount_out_reg']].sum()
gf_payment_pattern_reg['buffer'] = gf_payment_pattern_reg['amount_in'] + gf_payment_pattern_reg['amount_out_reg']
gf_payment_pattern_reg.head(10)
# Out:
#             amount_in  amount_out_reg       buffer
# year month
# 2018 2            0.0     -438.924523  -438.924523
#      3         2450.0     -438.924523  2011.075477
#      4         2450.0     -438.924523  2011.075477
#      5         2450.0     -438.924523  2011.075477
#      6         2450.0     -438.924523  2011.075477
#      7         2450.0     -438.924523  2011.075477
#      8         2450.0     -438.924523  2011.075477
#      9         2450.0     -438.924523  2011.075477
#      10        2450.0     -438.924523  2011.075477
#      11        2450.0     -438.924523  2011.075477

# %%
gf_payment_pattern_reg
# Out:
#             amount_in  amount_out_reg       buffer
# year month
# 2018 2            0.0     -438.924523  -438.924523
#      3         2450.0     -438.924523  2011.075477
#      4         2450.0     -438.924523  2011.075477
#      5         2450.0     -438.924523  2011.075477
#      6         2450.0     -438.924523  2011.075477
# ...               ...             ...          ...
# 2023 8         2450.0     -877.849046  1572.150954
#      9         2450.0     -438.924523  2011.075477
#      10        2450.0     -438.924523  2011.075477
#      11        2450.0     -438.924523  2011.075477
#      12        2450.0     -438.924523  2011.075477
#
# [71 rows x 3 columns]

# %%
df.tail() # 2018-02-16 - 2026-01-01
# Out:
#                    dates        account_name        account_IBAN  \
# 987  2025-10-31 17:55:15    Patrick Hamilton  CJVO60129798466874
# 988  2025-11-01 03:01:52  Katherine Valencia  DOJO46309747392475
# 989  2025-12-31 15:06:52  Katherine Valencia  DOJO46309747392475
# 990  2025-12-31 22:29:06    Patrick Hamilton  CJVO60129798466874
# 991  2026-01-01 01:04:31  Katherine Valencia  DOJO46309747392475
#
#     other_account_name     Type      amount       balance
# 987          Utilities  Regular -224.106675 -13653.319034
# 988    Medical Session  Regular -200.000000 -13853.319034
# 989          Utilities  Regular -206.107448 -14059.426481
# 990          Utilities  Regular -265.745032 -14325.171513
# 991    Medical Session  Regular -200.000000 -14525.171513

# %%
# Select for the same user and join on dates
df_user = df.loc[df['account_name'] == unique_name[1]].copy()

# %%
df_user['account_name'].value_counts()
# Out:
# Patrick Hamilton    489
# Name: account_name, dtype: int64

# %%
df_user['year'] = df_user['dates'].apply(lambda x: int(x[:4]))
df_user['month'] = df_user['dates'].apply(lambda x: int(x[5:7]))

# %%
df_user.head()
# Out:
#                  dates      account_name        account_IBAN  \
# 1  2018-02-20 14:29:42  Patrick Hamilton  CJVO60129798466874
# 5  2018-02-28 04:58:09  Patrick Hamilton  CJVO60129798466874
# 6  2018-02-28 07:10:24  Patrick Hamilton  CJVO60129798466874
# 8  2018-02-28 07:38:44  Patrick Hamilton  CJVO60129798466874
# 9  2018-02-28 07:41:58  Patrick Hamilton  CJVO60129798466874
#
#      other_account_name     Type       amount      balance  year  month
# 1           Wages MyOrg  Regular  2600.000000  4900.000000  2018      2
# 5         Rent - apt 12  Regular -1500.000000  3106.422271  2018      2
# 6             Utilities  Regular  -204.099259  2902.323012  2018      2
# 8       Medical Session  Regular  -200.000000  2372.323012  2018      2
# 9  Medical Subscription  Regular  -150.000000  2222.323012  2018      2

# %%
# Promote multi-index
gf_payment_pattern_reg = gf_payment_pattern_reg.reset_index()

# %%
df_join = pd.merge(df_user,gf_payment_pattern_reg, how = 'left', on = ['year','month'])

# %%
df_join.shape
# Out:
# (489, 12)

# %%
df_join.head()
# Out:
#                  dates      account_name        account_IBAN  \
# 0  2018-02-20 14:29:42  Patrick Hamilton  CJVO60129798466874
# 1  2018-02-28 04:58:09  Patrick Hamilton  CJVO60129798466874
# 2  2018-02-28 07:10:24  Patrick Hamilton  CJVO60129798466874
# 3  2018-02-28 07:38:44  Patrick Hamilton  CJVO60129798466874
# 4  2018-02-28 07:41:58  Patrick Hamilton  CJVO60129798466874
#
#      other_account_name     Type       amount      balance  year  month  \
# 0           Wages MyOrg  Regular  2600.000000  4900.000000  2018      2
# 1         Rent - apt 12  Regular -1500.000000  3106.422271  2018      2
# 2             Utilities  Regular  -204.099259  2902.323012  2018      2
# 3       Medical Session  Regular  -200.000000  2372.323012  2018      2
# 4  Medical Subscription  Regular  -150.000000  2222.323012  2018      2
#
#    amount_in  amount_out_reg      buffer
# 0        0.0     -438.924523 -438.924523
# 1        0.0     -438.924523 -438.924523
# 2        0.0     -438.924523 -438.924523
# 3        0.0     -438.924523 -438.924523
# 4        0.0     -438.924523 -438.924523

# %%
df_join.loc[df_join['Type'] == 'Discretionary']
# Out:
#                    dates      account_name        account_IBAN  \
# 17   2018-03-28 00:13:24  Patrick Hamilton  CJVO60129798466874
# 26   2018-04-04 00:09:47  Patrick Hamilton  CJVO60129798466874
# 36   2018-04-28 00:05:25  Patrick Hamilton  CJVO60129798466874
# 101  2018-08-28 00:16:01  Patrick Hamilton  CJVO60129798466874
# 102  2018-08-28 01:07:51  Patrick Hamilton  CJVO60129798466874
# 103  2018-08-28 02:02:24  Patrick Hamilton  CJVO60129798466874
# 106  2018-08-28 03:14:57  Patrick Hamilton  CJVO60129798466874
# 107  2018-08-28 04:22:36  Patrick Hamilton  CJVO60129798466874
# 108  2018-08-28 05:03:31  Patrick Hamilton  CJVO60129798466874
#
#     other_account_name           Type      amount       balance  year  month  \
# 17               Group  Discretionary  -52.937404   2890.992954  2018      3
# 26               Group  Discretionary  -53.677123  -1619.806819  2018      4
# 36                 PLC  Discretionary -300.248394    464.276739  2018      4
# 101                Ltd  Discretionary -178.118546  -9904.445118  2018      8
# 102                Ltd  Discretionary -165.192943 -10069.638060  2018      8
# 103                Ltd  Discretionary -150.891980 -10495.170945  2018      8
# 106                Ltd  Discretionary -188.345988 -12580.964803  2018      8
# 107                Ltd  Discretionary -157.212235 -12944.330104  2018      8
# 108                Ltd  Discretionary -188.881820 -13267.276715  2018      8
#
#      amount_in  amount_out_reg       buffer
# 17      2450.0     -438.924523  2011.075477
# 26      2450.0     -438.924523  2011.075477
# 36      2450.0     -438.924523  2011.075477
# 101     2450.0     -438.924523  2011.075477
# 102     2450.0     -438.924523  2011.075477
# 103     2450.0     -438.924523  2011.075477
# 106     2450.0     -438.924523  2011.075477
# 107     2450.0     -438.924523  2011.075477
# 108     2450.0     -438.924523  2011.075477

# %%
# If amount > buffer, then depends on balance
def gt_buffer(row):
    amount = row['amount']
    buffer = row['buffer']
    txn_type = row['Type']
    other_account_name = row['other_account_name']
    
    alert_dict = {}
    if txn_type != 'Regular':
        if abs(amount) > abs(buffer):
            print('Payment of {} to {} exceeds the projected buffer between regular incoming and outgoing payments this month - are you sure?')
            alert_dict.update({other_account_name, amount, buffer})
            
    return alert_dict

# %%
df_join.apply(gt_buffer, axis = 1)
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 484    {}
# 485    {}
# 486    {}
# 487    {}
# 488    {}
# Length: 489, dtype: object

# %%
# Try hitting the API Endpoint
import requests
json_data = df.to_json()
r = requests.post('https://demo-app-lquvhriy2a-ew.a.run.app/service/forecast_v2/',  json= {"data":json_data})
r.json()
# Out:
# '{"dates":{"0":"2018-02-16 02:17:13","1":"2018-02-20 14:29:42","2":"2018-02-25 21:12:59","3":"2018-02-28 01:18:39","4":"2018-02-28 03:02:54","5":"2018-02-28 04:58:09","6":"2018-02-28 07:10:24","7":"2018-02-28 07:15:31","8":"2018-02-28 07:38:44","9":"2018-02-28 07:41:58","10":"2018-02-28 07:52:35","11":"2018-02-28 08:09:57","12":"2018-02-28 08:19:09","13":"2018-02-28 08:43:13","14":"2018-02-28 08:49:09","15":"2018-02-28 09:05:45","16":"2018-02-28 18:43:49","17":"2018-03-01 01:32:13","18":"2018-03-01 02:43:29","19":"2018-03-01 03:21:51","20":"2018-03-05 02:51:29","21":"2018-03-07 10:58:58","22":"2018-03-07 13:23:32","23":"2018-03-07 15:47:40","24":"2018-03-11 03:45:17","25":"2018-03-14 00:41:47","26":"2018-03-14 02:22:12","27":"2018-03-14 14:35:21","28":"2018-03-15 17:13:08","29":"2018-03-19 05:03:24","30":"2018-03-20 06:07:48","31":"2018-03-21 00:26:48","32":"2018-03-21 16:05:40","33":"2018-03-22 04:58:51","34":"2018-03-25 11:01:36","35":"2018-03-28 00:13:24","36":"2018-03-28 00:27:57","37":"2018-03-28 00:35:27","38":"2018-03-28 02:36:47","39":"2018-03-28 04:15:55","40":"2018-03-28 04:33:52","41":"2018-03-28 05:40:32","42":"2018-03-28 05:42:36","43":"2018-03-28 07:16:06","44":"2018-03-28 08:38:13","45":"2018-03-28 11:14:03","46":"2018-03-28 12:14:27","47":"2018-03-28 12:57:06","48":"2018-03-28 12:59:38","49":"2018-03-28 14:55:52","50":"2018-03-28 22:55:23","51":"2018-04-01 06:33:20","52":"2018-04-04 00:09:47","53":"2018-04-04 00:26:55","54":"2018-04-04 05:13:30","55":"2018-04-04 13:00:06","56":"2018-04-04 18:07:56","57":"2018-04-08 22:57:47","58":"2018-04-11 00:11:26","59":"2018-04-11 16:10:17","60":"2018-04-11 21:24:48","61":"2018-04-12 03:49:42","62":"2018-04-15 04:18:51","63":"2018-04-16 02:25:01","64":"2018-04-18 00:15:00","65":"2018-04-18 03:45:43","66":"2018-04-18 22:44:25","67":"2018-04-19 05:25:45","68":"2018-04-20 23:40:08","69":"2018-04-22 14:30:09","70":"2018-04-25 00:17:12","71":"2018-04-25 04:22:50","72":"2018-04-25 12:11:38","73":"2018-04-26 00:32:10","74":"2018-04-28 00:00:47","75":"2018-04-28 00:05:25","76":"2018-04-28 08:44:05","77":"2018-04-28 10:57:12","78":"2018-04-28 12:29:26","79":"2018-04-28 14:34:55","80":"2018-04-28 17:32:31","81":"2018-04-28 21:52:22","82":"2018-04-28 23:48:57","83":"2018-04-29 00:14:39","84":"2018-04-29 02:02:03","85":"2018-04-29 02:24:41","86":"2018-04-29 02:48:11","87":"2018-04-29 05:00:08","88":"2018-04-30 00:02:21","89":"2018-04-30 03:09:01","90":"2018-04-30 08:28:15","91":"2018-05-01 00:28:28","92":"2018-05-01 01:36:19","93":"2018-05-01 03:03:45","94":"2018-05-02 00:02:55","95":"2018-05-02 00:15:04","96":"2018-05-02 00:54:18","97":"2018-05-02 07:40:22","98":"2018-05-03 00:06:22","99":"2018-05-03 02:08:50","100":"2018-05-04 00:01:44","101":"2018-05-05 00:05:54","102":"2018-05-06 00:18:17","103":"2018-05-06 17:32:36","104":"2018-05-07 00:16:27","105":"2018-05-09 00:01:36","106":"2018-05-09 00:20:07","107":"2018-05-09 00:31:45","108":"2018-05-09 17:51:45","109":"2018-05-13 09:38:49","110":"2018-05-15 23:10:35","111":"2018-05-16 02:29:46","112":"2018-05-16 15:36:29","113":"2018-05-17 02:24:41","114":"2018-05-20 09:02:51","115":"2018-05-20 21:30:54","116":"2018-05-23 15:13:25","117":"2018-05-23 22:14:16","118":"2018-05-24 05:26:45","119":"2018-05-27 03:17:44","120":"2018-05-28 08:11:18","121":"2018-05-28 08:11:58","122":"2018-05-28 10:11:55","123":"2018-05-28 11:05:51","124":"2018-05-28 11:20:20","125":"2018-05-28 12:02:27","126":"2018-05-28 15:01:42","127":"2018-05-28 19:36:41","128":"2018-05-28 22:05:43","129":"2018-05-29 04:21:53","130":"2018-05-29 04:36:02","131":"2018-05-30 11:58:51","132":"2018-05-30 23:32:51","133":"2018-05-31 04:54:53","134":"2018-06-03 05:28:09","135":"2018-06-06 00:50:07","136":"2018-06-06 12:36:28","137":"2018-06-06 20:59:25","138":"2018-06-10 04:05:19","139":"2018-06-13 06:41:01","140":"2018-06-13 09:05:48","141":"2018-06-13 20:48:05","142":"2018-06-15 04:55:12","143":"2018-06-17 16:39:12","144":"2018-06-20 00:35:15","145":"2018-06-20 01:33:56","146":"2018 ...

# %%
r
# Out:
# <Response [200]>
